# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create an empty bidirected graph
graph = nx.DiGraph()



# Add nodes to the graph
graph.add_node('A', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87494,79.875717&heading=176.41&pitch=-0.76&key=')
graph.add_node('B', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87666,79.886933&heading=68.82&pitch=-0.76&key=')
graph.add_node('C', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.86803,79.880366&heading=329.16&pitch=-0.76&key=') 
graph.add_node('D', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87475,79.888500&heading=201.65&pitch=-0.76&key=')
graph.add_node('E', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87475,79.888500&heading=201.65&pitch=-0.76&key=')
graph.add_node('F', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87244,79.885716&heading=178.19&pitch=-0.76&key=')
graph.add_node('G', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87804,79.877128&heading=283.36&pitch=-0.76&key=')
graph.add_node('H', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87683,79.890067&heading=265.48&pitch=-0.76&key=')
graph.add_node('I', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87793,79.890643&heading=272.30&pitch=-0.76&key=')
graph.add_node('J', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87787,79.878053&heading=103.81&pitch=-0.76&key=')
graph.add_node('K', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.86635,79.871131&heading=8.93&pitch=-0.76&key=')
graph.add_node('L', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.86376,79.885020&heading=75.72&pitch=-0.76&key=')
graph.add_node('M', stview='https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.86574,79.885480&heading=348.43&pitch=-0.76&key=')

# Add edges with directions as attributes
graph.add_edge('A', 'B', direction='forward')
graph.add_edge('B', 'A', direction='backward')
graph.add_edge('B', 'C', direction='forward')
graph.add_edge('C', 'B', direction='backward')
graph.add_edge('C', 'D', direction='left')
graph.add_edge('D', 'C', direction='right')
graph.add_edge('C', 'E', direction='right')
graph.add_edge('E', 'C', direction='left')
graph.add_edge('C', 'F', direction='forward')
graph.add_edge('F', 'C', direction='backward')
graph.add_edge('D', 'F', direction='left')
graph.add_edge('F', 'D', direction='right')
graph.add_edge('D', 'E', direction='forward')
graph.add_edge('E', 'D', direction='backward')
graph.add_edge('E', 'F', direction='right')
graph.add_edge('F', 'E', direction='left')
graph.add_edge('F', 'G', direction='forward')
graph.add_edge('G', 'F', direction='backward')
graph.add_edge('G', 'H', direction='left')
graph.add_edge('H', 'G', direction='right')
graph.add_edge('G', 'I', direction='forward')
graph.add_edge('H', 'I', direction='left')
graph.add_edge('I', 'H', direction='right')
graph.add_edge('I', 'G', direction='backward')
graph.add_edge('I', 'J', direction='forward')
graph.add_edge('J', 'I', direction='backward')
graph.add_edge('J', 'L', direction='right')
graph.add_edge('L', 'J', direction='left')
graph.add_edge('J', 'M', direction='left')
graph.add_edge('M', 'J', direction='right')
graph.add_edge('J', 'K', direction='forward')
graph.add_edge('K', 'J', direction='backward')
graph.add_edge('M', 'L', direction='forward')
graph.add_edge('L', 'M', direction='backward')
graph.add_edge('M', 'K', direction='left')
graph.add_edge('K', 'M', direction='right')
graph.add_edge('K', 'L', direction='left')
graph.add_edge('L', 'K', direction='right')


# Access and print edge directions
print("Edge directions:")
for u, v, attrs in graph.edges(data=True):
    direction = attrs['direction']
    print(f"From {u} to {v}: {direction}")

# Draw the graph
nx.draw(graph, with_labels=True, node_size=50, node_color='lightblue', font_size=10, font_color='black', edge_color='gray')

# Show the graph
plt.show()
# Out:
# Edge directions:
# From A to B: forward
# From B to A: backward
# From B to C: forward
# From C to B: backward
# From C to D: left
# From C to E: right
# From C to F: forward
# From D to C: right
# From D to F: left
# From D to E: forward
# From E to C: left
# From E to D: backward
# From E to F: right
# From F to C: backward
# From F to D: right
# From F to E: left
# From F to G: forward
# From G to F: backward
# From G to H: left
# From G to I: forward
# From H to G: right
# From H to I: left
# From I to H: right
# From I to G: backward
# From I to J: forward
# From J to I: backward
# From J to L: right
# From J to M: left
# From J to K: forward
# From K to J: backward
# From K to M: right
# From K to L: left
# From L to J: left
# From L to M: backward
# From L to K: right
# From M to J: right
# From M to L: forward
# From M to K: left

# %%
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(graph, seed=42)
nx.draw(graph, pos, with_labels=True, node_size=1500, node_color='skyblue', font_size=12, font_weight='bold', arrowsize=20)

# Add edge labels for 'direction' attribute
edge_labels = nx.get_edge_attributes(graph, 'direction')
nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels, font_size=10, font_weight='bold')

# Show the plot
plt.title('Directed Graph with Edge Directions')
plt.axis('off')
plt.show()

# %%
attributes = graph.get_edge_data('A', 'B')
attributes
# Out:
# {'direction': 'forward'}

# %%
for node, attrs in graph.nodes(data=True):
    print(f"Node {node}: {attrs}")
# Out:
# Node A: {'stview': 'https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87494,79.875717&heading=176.41&pitch=-0.76&key='}
# Node B: {'stview': 'https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87666,79.886933&heading=68.82&pitch=-0.76&key='}
# Node C: {'stview': 'https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.86803,79.880366&heading=329.16&pitch=-0.76&key='}
# Node D: {'stview': 'https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87475,79.888500&heading=201.65&pitch=-0.76&key='}
# Node E: {'stview': 'https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87475,79.888500&heading=201.65&pitch=-0.76&key='}
# Node F: {'stview': 'https://maps.googleapis.com/maps/api/streetview?size=600x400&location=6.87244,79.885716&heading=178.19&pitch=-0.76&key='}
# ...

# %%
# attribute_value = graph.nodes['A']['stview']
# print(attribute_value)

# %%
graph.nodes.items()
# Out:
# ItemsView(NodeView(('A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M')))

# %%
# Save the graph in GraphML format
nx.write_graphml(graph, "route.graphml")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\isu_v\Desktop\langchain\topo_graph.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/isu_v/Desktop/langchain/topo_graph.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # Save the graph in GraphML format
# ----> <a href='vscode-notebook-cell:/c%3A/Users/isu_v/Desktop/langchain/topo_graph.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> nx.write_graphml(graph, "route.graphml")
#
# NameError: name 'nx' is not defined

# %%
################ Synthetic graph for study

# %%
import os
from urllib.parse import urlencode

filepaths = [r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_Elitl84q-5FIAleLdYoX6g_255.55_52.37126_4.879865.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_Bt-vhCftot-r1d4YUaKGWw_255.55_52.37140_4.880406.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_x3lXT7HT0tyYF5f3qqYeLA_255.55_52.37151_4.880832.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_Mm2wLFzbWr5vgURbauf9Ow_255.32_52.37171_4.881606.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_TDiuod8-f3WrcKvLbayLTA_255.32_52.37185_4.882155.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_sJ-wCi542vpk3346IFbkRw_145.69_52.37138_4.879431.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_8Z5bjuz6rbMdj6XKjNjWQw_144.70_52.37184_4.881215.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_I5Q3xLn7KXNdfIlhxruVNg_92.41_52.37239_4.882656.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_k7mZBDKV9360g_2Q_0-yJA_185.83_52.37321_4.882716.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_gaCHmZ5auD7PviESg9xoIQ_91.96_52.37239_4.883713.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_1vdbypxUo_YgHUBKPlemCg_255.62_52.37174_4.879177.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_nLCbrm7XmyjZIDd81aocdg_255.62_52.37218_4.880929.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_Oh91Ekd6_mdoH-EX_rDs2Q_93.27_52.37242_4.883195.png",
 r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_WW6p7W8sjlAxWwWBlSLhgA_92.10_52.37235_4.885002.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_kjrbi2mXcN2Nn076q74-PQ_255.62_52.37184_4.879554.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_cOCpACwWE3LO695TbTB0mw_255.62_52.37194_4.879978.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_DWhcuOnoxm5rl1hUYmi2mw_255.62_52.37208_4.880521.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_aan7jsJwsxvWhxjxgzlxyg_255.69_52.37226_4.881239.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_jqf5XF62MbRKem7fRgbNag_255.69_52.37237_4.881647.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_J3D-ML2yy44YYVrrAyKexQ_255.69_52.37251_4.882191.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_6XPsoyDD7DtXW9G1ybUa-g_185.83_52.37263_4.882651.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_nn11xpR1Vp1VBSW6nsvXug_5.59_52.37293_4.883235.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_-HMkhekVhtUjYhqKC4aTeQ_325.24_52.37220_4.878883.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_SNdoRTqRF0zDCJ-xaNfYjQ_145.50_52.37223_4.880942.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_FN-BFnGLgw0GlO4bP5k5Lg_185.83_52.37272_4.882682.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_ZTkaDtuhaupsOJoeU-H8bA_255.29_52.37222_4.878837.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_8cJtQ9oF4DUsOtJr-Ou-8A_255.29_52.37267_4.880611.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_jL4u7KU8B7eHYKyEaJwA8Q_255.29_52.37229_4.879116.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_VEGjwOY4ihU_Gwt1HZV8Vg_255.29_52.37243_4.879685.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_hTJLQwSkLcresnsKFO-bqg_255.29_52.37254_4.880099.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_OOQIv_1DOD5zbLGU1QJ2tw_255.72_52.37273_4.880832.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_g149g1vrvnwYCHLcdmGbgA_255.72_52.37285_4.881296.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_RT3ocdq01HJOBA64g-u2NA_255.72_52.37296_4.881725.png",
r"C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\imgs_amsterdam\head_cjA3JgHP5esj2AOoDXQ5jw_255.72_52.37308_4.882188.png"]

# Example local file path
# local_file_path = r'C:\Users\isu_v\Desktop\langchain\image_description\sandbox_img_selection\selected\head_6RSvn82tow0ZvykEOca1Gw_192.02_52.37220_4.888163.png'

for each in filepaths:

    # Extract location and pitch from the local file path
    filename = os.path.basename(each)

    # newname = filename.split(".")[0]
    newname = filename.split("_")

    # print(newname)

    # Construct Google Street View API URL
    google_api_url = 'https://maps.googleapis.com/maps/api/streetview?'
    # parameters = {
    #     'size': '400x400',
    #     'location': f'{newname[3]},{newname[4].strip(".png")}',
    #     'pitch': newname[2],
    #     'key': 'YOUR_API_KEY',  # Replace with your Google API key
    # }

    google_api_url += f'size=400x400&location={newname[-2]},{newname[-1].strip(".png")}&heading={newname[-3]}&pitch=-0.76&key='  

    # Print the constructed URL
    print(google_api_url)
# Out:
# https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37126,4.879865&heading=255.55&pitch=-0.76&key=
# https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37140,4.880406&heading=255.55&pitch=-0.76&key=
# https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37151,4.880832&heading=255.55&pitch=-0.76&key=
# https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37171,4.881606&heading=255.32&pitch=-0.76&key=
# https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37185,4.882155&heading=255.32&pitch=-0.76&key=
# https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37138,4.879431&heading=145.69&pitch=-0.76&key=
# https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37184,4.881215&heading=144.70&pitch=-0.76&key=
# https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37239,4.882656&heading=92.41&pitch=-0.76&key=
# ...

# %%
# Out:
# Edge directions:
# From A to B: forward
# From A to F: right
# From B to A: backward
# From B to C: forward
# From C to B: backward
# From C to D: forward
# From C to G: left
# From D to C: backward
# From D to G: right
# From D to E: forward
# From E to D: backward
# From E to H: forward
# From F to A: left
# From F to K: forward
# From G to L: forward
# From G to C: right
# From G to D: left
# From H to T: right
# From H to M1: right
# From H to E: backward
# From I to M: left
# From I to U: forward
# From I to J: right
# From J to I: left
# From J to M: forward
# From J to U: right
# From K to V: forward
# From K to N: right
# From K to F: backward
# From L to G: backward
# From L to P: left
# From L to Q: right
# From L to W: forward
# From M to J: forward
# From M to U: left
# From M to I: right
# From M to M1: backward
# From M1 to M: forward
# From M1 to T: right
# From M1 to H: left
# From N to O: forward
# From N to V: right
# From N to K: left
# From O to P: forward
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create an empty bidirected graph
graph = nx.DiGraph()



# Create an empty bidirected graph
graph = nx.DiGraph()



# Add nodes to the graph
graph.add_node('A', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37220,4.888163&heading=192.02&pitch=-0.76&key=") ### residential_promenade
graph.add_node('B', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.36791,4.888490&heading=126.72&pitch=-0.76&key=") ### people_campus_ 
graph.add_node('C', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37226,4.887343&heading=5.89&pitch=-0.76&key=")##people_residential_train_platform
graph.add_node('D', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.36813,4.887931&heading=70.04&pitch=-0.76&key=") ## alley_residential
graph.add_node('E', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37386,4.880128&heading=76.94&pitch=-0.76&key=")  ## alley_garbage
graph.add_node('F', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37528,4.878675&heading=148.00&pitch=-0.76&key=")  ## "alley"_courtyard_neighborhood
graph.add_node('G', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37117,4.879570&heading=144.18&pitch=-0.76&key=") ## promenade_canal_plaza
graph.add_node('H', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37387,4.895408&heading=289.18&pitch=-0.76&key=") ##alley_jailcell
graph.add_node('I', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37497,4.881495&heading=257.00&pitch=-0.76&key=") ##residential_canal_promenade
graph.add_node('J', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.36510,4.885954&heading=121.92&pitch=-0.76&key=") ## alley_crosswalk
graph.add_node('K', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.36825,4.897534&heading=93.58&pitch=-0.76&key=") ## arch_aqueduct_viaduct
graph.add_node('L', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.36340,4.888652&heading=281.48&pitch=-0.76&key=") ##promenade_hotel_plaza
graph.add_node('M', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37394,4.885238&heading=98.13&pitch=-0.76&key=") ##canal_urban_promenade_construction
graph.add_node('N', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.36876,4.879876&heading=140.99&pitch=-0.76&key=") ##alley_embassy
graph.add_node('O', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37076,4.886696&heading=185.76&pitch=-0.76&key=") ### canal_promenade_beachhouse
graph.add_node('P', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.36391,4.881759&heading=299.26&pitch=-0.76&key=")  ##restaurant


# Add edges with directions as attributes
graph.add_edge('A', 'B', direction='right')
graph.add_edge('A', 'E', direction='forward')
graph.add_edge('B', 'A', direction='left')
graph.add_edge('B', 'C', direction='right')
graph.add_edge('B', 'F', direction='forward')
graph.add_edge('C', 'B', direction='left')
graph.add_edge('C', 'D', direction='right')
graph.add_edge('C', 'G', direction='forward')
graph.add_edge('D', 'C', direction='left')
graph.add_edge('D', 'H', direction='forward')
graph.add_edge('E', 'A', direction='backward')
graph.add_edge('E', 'I', direction='forward')
graph.add_edge('E', 'F', direction='right')
graph.add_edge('F', 'E', direction='left')
graph.add_edge('F', 'J', direction='forward')
graph.add_edge('F', 'B', direction='backward')
graph.add_edge('F', 'G', direction='right')
graph.add_edge('G', 'F', direction='left')
graph.add_edge('G', 'C', direction='backward')
graph.add_edge('G', 'H', direction='right')
graph.add_edge('G', 'K', direction='forward')
graph.add_edge('H', 'G', direction='left')
graph.add_edge('H', 'D', direction='backward')
graph.add_edge('H', 'L', direction='forward')
graph.add_edge('I', 'E', direction='backward')
graph.add_edge('I', 'J', direction='right')
graph.add_edge('I', 'M', direction='forward')
graph.add_edge('J', 'I', direction='left')
graph.add_edge('J', 'F', direction='backward')
graph.add_edge('J', 'K', direction='right')
graph.add_edge('J', 'N', direction='forward')
graph.add_edge('K', 'J', direction='left')
graph.add_edge('K', 'O', direction='forward')
graph.add_edge('K', 'G', direction='backward')
graph.add_edge('K', 'L', direction='right')
graph.add_edge('L', 'K', direction='left')
graph.add_edge('L', 'H', direction='backward')
graph.add_edge('L', 'P', direction='forward')
graph.add_edge('M', 'I', direction='backward')
graph.add_edge('M', 'N', direction='right')
graph.add_edge('N', 'M', direction='left')
graph.add_edge('N', 'J', direction='backward')
graph.add_edge('N', 'O', direction='right')
graph.add_edge('O', 'N', direction='left')
graph.add_edge('O', 'K', direction='backward')
graph.add_edge('O', 'P', direction='right')
graph.add_edge('P', 'O', direction='left')
graph.add_edge('P', 'L', direction='backward')


# Access and print edge directions
print("Edge directions:")
for u, v, attrs in graph.edges(data=True):
    direction = attrs['direction']
    print(f"From {u} to {v}: {direction}")

# Draw the graph
nx.draw(graph, with_labels=True, node_size=50, node_color='lightblue', font_size=10, font_color='black', edge_color='gray')

# Show the graph
plt.show()
# Out:
# Edge directions:
# From A to B: right
# From A to E: forward
# From B to A: left
# From B to C: right
# From B to F: forward
# From C to B: left
# From C to D: right
# From C to G: forward
# From D to C: left
# From D to H: forward
# From E to A: backward
# From E to I: forward
# From E to F: right
# From F to E: left
# From F to J: forward
# From F to B: backward
# From F to G: right
# From G to F: left
# From G to C: backward
# From G to H: right
# From G to K: forward
# From H to G: left
# From H to D: backward
# From H to L: forward
# From I to E: backward
# From I to J: right
# From I to M: forward
# From J to I: left
# From J to F: backward
# From J to K: right
# From J to N: forward
# From K to J: left
# From K to O: forward
# From K to G: backward
# From K to L: right
# From L to K: left
# From L to H: backward
# From L to P: forward
# From M to I: backward
# From M to N: right
# From N to M: left
# From N to J: backward
# From N to O: right
# From O to N: left
# ...

# %%
plt.figure(figsize=(10, 10))
pos = nx.spring_layout(graph, seed=42)
nx.draw(graph, pos, with_labels=True, node_size=1500, node_color='skyblue', font_size=12, font_weight='bold', arrowsize=20)

# Add edge labels for 'direction' attribute
edge_labels = nx.get_edge_attributes(graph, 'direction')
nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels, font_size=10, font_weight='bold')

# Show the plot
plt.title('Directed Graph with Edge Directions')
plt.axis('off')
plt.show()

# %%
# Save the graph in GraphML format
nx.write_graphml(graph, "synthetic_route.graphml")

# %%
################ Amsterdam graph for study

import networkx as nx
import matplotlib.pyplot as plt

# Create an empty bidirected graph
graph = nx.DiGraph()



# Add nodes to the graph
graph.add_node('A', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37126,4.879865&heading=255.55&pitch=-0.76&key=")
graph.add_node('B', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37140,4.880406&heading=255.55&pitch=-0.76&key=")
graph.add_node('C', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37151,4.880832&heading=255.55&pitch=-0.76&key=") 
graph.add_node('D', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37171,4.881606&heading=255.32&pitch=-0.76&key=")
graph.add_node('E', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37185,4.882155&heading=255.32&pitch=-0.76&key=")
graph.add_node('F', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37138,4.879431&heading=145.69&pitch=-0.76&key=")
graph.add_node('G', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37184,4.881215&heading=144.70&pitch=-0.76&key=")
graph.add_node('H', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37239,4.882656&heading=92.41&pitch=-0.76&key=")
graph.add_node('I', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37321,4.882716&heading=185.83&pitch=-0.76&key=")
graph.add_node('J', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37239,4.883713&heading=91.96&pitch=-0.76&key=")
graph.add_node('K', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37174,4.879177&heading=255.62&pitch=-0.76&key=")
graph.add_node('L', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37218,4.880929&heading=255.62&pitch=-0.76&key=")
graph.add_node('M', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37242,4.883195&heading=93.27&pitch=-0.76&key=")
graph.add_node('M1', stview="https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37235,4.885002&heading=92.10&pitch=-0.76&key=")
graph.add_node('N', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37184,4.879554&heading=255.62&pitch=-0.76&key=")
graph.add_node('O', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37194,4.879978&heading=255.62&pitch=-0.76&key=")
graph.add_node('P', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37208,4.880521&heading=255.62&pitch=-0.76&key=")
graph.add_node('Q', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37226,4.881239&heading=255.69&pitch=-0.76&key=")
graph.add_node('R', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37237,4.881647&heading=255.69&pitch=-0.76&key=")
graph.add_node('S', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37251,4.882191&heading=255.69&pitch=-0.76&key=")
graph.add_node('T', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37263,4.882651&heading=185.83&pitch=-0.76&key=")
graph.add_node('U', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37293,4.883235&heading=5.59&pitch=-0.76&key=")
graph.add_node('V', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37220,4.878883&heading=325.24&pitch=-0.76&key=")
graph.add_node('W', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37223,4.880942&heading=145.50&pitch=-0.76&key=")
graph.add_node('X', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37272,4.882682&heading=185.83&pitch=-0.76&key=")
graph.add_node('Y', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37222,4.878837&heading=255.29&pitch=-0.76&key=")
graph.add_node('Z', stview= "https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37267,4.880611&heading=255.29&pitch=-0.76&key=")
graph.add_node('1A', stview="https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37229,4.879116&heading=255.29&pitch=-0.76&key=")
graph.add_node('1B', stview="https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37243,4.879685&heading=255.29&pitch=-0.76&key=")
graph.add_node('1C', stview="https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37254,4.880099&heading=255.29&pitch=-0.76&key=")
graph.add_node('1D', stview="https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37273,4.880832&heading=255.72&pitch=-0.76&key=")
graph.add_node('1E', stview="https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37285,4.881296&heading=255.72&pitch=-0.76&key=")
graph.add_node('1F', stview="https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37296,4.881725&heading=255.72&pitch=-0.76&key=")
graph.add_node('1G', stview="https://maps.googleapis.com/maps/api/streetview?size=400x400&location=52.37308,4.882188&heading=255.72&pitch=-0.76&key=")


# Add edges with directions as attributes
graph.add_edge('A', 'B', direction='forward')
graph.add_edge('A', 'F', direction='right')
graph.add_edge('B', 'A', direction='backward')
graph.add_edge('B', 'C', direction='forward')
graph.add_edge('C', 'B', direction='backward')
graph.add_edge('C', 'D', direction='forward')
graph.add_edge('C', 'G', direction='left')
graph.add_edge('D', 'C', direction='backward')
graph.add_edge('D', 'G', direction='right')
graph.add_edge('D', 'E', direction='forward')
graph.add_edge('E', 'D', direction='backward')
graph.add_edge('E', 'H', direction='forward')
graph.add_edge('F', 'A', direction='left')
graph.add_edge('F', 'K', direction='forward')
graph.add_edge('G', 'L', direction='forward')
graph.add_edge('G', 'C', direction='right')
graph.add_edge('G', 'D', direction='left')
graph.add_edge('H', 'T', direction='right')
graph.add_edge('H', 'M1', direction='right')
graph.add_edge('H', 'E', direction='backward')
graph.add_edge('I', 'M', direction='left')
graph.add_edge('I', 'U', direction='forward')
graph.add_edge('I', 'J', direction='right')
graph.add_edge('J', 'I', direction='left')
graph.add_edge('J', 'M', direction='forward')
graph.add_edge('J', 'U', direction='right')
graph.add_edge('K', 'V', direction='forward')
graph.add_edge('K', 'N', direction='right')
graph.add_edge('K', 'F', direction='backward')
graph.add_edge('L', 'G', direction='backward')
graph.add_edge('L', 'P', direction='left')
graph.add_edge('L', 'Q', direction='right')
graph.add_edge('L', 'W', direction='forward')
graph.add_edge('M', 'J', direction='forward')
graph.add_edge('M', 'U', direction='left')
graph.add_edge('M', 'I', direction='right')
graph.add_edge('M', 'M1', direction='backward')
graph.add_edge('M1', 'M', direction='forward')
graph.add_edge('M1', 'T', direction='right')
graph.add_edge('M1', 'H', direction='left')
graph.add_edge('N', 'O', direction='forward')
graph.add_edge('N', 'V', direction='right')
graph.add_edge('N', 'K', direction='left')
graph.add_edge('O', 'P', direction='forward')
graph.add_edge('O', 'N', direction='backward')
graph.add_edge('P', 'W', direction='left')
graph.add_edge('P', 'Q', direction='forward')
graph.add_edge('P', 'L', direction='right')
graph.add_edge('P', 'O', direction='backward')
graph.add_edge('Q', 'W', direction='right')
graph.add_edge('Q', 'P', direction='forward')
graph.add_edge('Q', 'L', direction='left')
graph.add_edge('Q', 'R', direction='forward')
graph.add_edge('R', 'Q', direction='backward')
graph.add_edge('R', 'S', direction='forward')
graph.add_edge('S', 'T', direction='right')
graph.add_edge('S', 'R', direction='backward')
graph.add_edge('S', 'X', direction='left')
graph.add_edge('T', 'S', direction='left')
graph.add_edge('T', 'X', direction='forward')
graph.add_edge('T', 'M1', direction='right')
graph.add_edge('T', 'H', direction='backward')
graph.add_edge('U', 'M', direction='right')
graph.add_edge('U', 'I', direction='forward')
graph.add_edge('U', 'J', direction='left')
graph.add_edge('V', 'N', direction='left')
graph.add_edge('V', 'K', direction='backward')
graph.add_edge('V', 'Y', direction='forward')
graph.add_edge('W', 'P', direction='right')
graph.add_edge('W', 'L', direction='backward')
graph.add_edge('W', 'Q', direction='left')
graph.add_edge('W', 'Z', direction='forward')
graph.add_edge('X', '1G', direction='forward')
graph.add_edge('X', 'T', direction='backward')
graph.add_edge('X', 'S', direction='right')
graph.add_edge('Y', '1A', direction='right')
graph.add_edge('Y', 'V', direction='backward')
graph.add_edge('Z', 'W', direction='backward')
graph.add_edge('Z', '1C', direction='left')
graph.add_edge('Z', '1D', direction='right')
graph.add_edge('1A', 'Y', direction='left')
graph.add_edge('1A', '1B', direction='forward')
graph.add_edge('1B', '1C', direction='forward')
graph.add_edge('1B', '1A', direction='backward')
graph.add_edge('1C', 'Z', direction='right')
graph.add_edge('1C', '1D', direction='forward')
graph.add_edge('1C', '1B', direction='backward')
graph.add_edge('1D', '1C', direction='backward')
graph.add_edge('1D', 'Z', direction='left')
graph.add_edge('1D', '1E', direction='forward')
graph.add_edge('1E', '1D', direction='backward')
graph.add_edge('1E', '1F', direction='forward')
graph.add_edge('1F', '1E', direction='backward')
graph.add_edge('1F', '1G', direction='forward')
graph.add_edge('1G', 'X', direction='right')
graph.add_edge('1G', '1F', direction='backward')


# Access and print edge directions
print("Edge directions:")
for u, v, attrs in graph.edges(data=True):
    direction = attrs['direction']
    print(f"From {u} to {v}: {direction}")

# Draw the graph
nx.draw(graph, with_labels=True, node_size=50, node_color='lightblue', font_size=10, font_color='black', edge_color='gray')

# Show the graph
plt.show()
# Out:
# Edge directions:
# From A to B: forward
# From A to F: right
# From B to A: backward
# From B to C: forward
# From C to B: backward
# From C to D: forward
# From C to G: left
# From D to C: backward
# From D to G: right
# From D to E: forward
# From E to D: backward
# From E to H: forward
# From F to A: left
# From F to K: forward
# From G to L: forward
# From G to C: right
# From G to D: left
# From H to T: right
# From H to M1: right
# From H to E: backward
# From I to M: left
# From I to U: forward
# From I to J: right
# From J to I: left
# From J to M: forward
# From J to U: right
# From K to V: forward
# From K to N: right
# From K to F: backward
# From L to G: backward
# From L to P: left
# From L to Q: right
# From L to W: forward
# From M to J: forward
# From M to U: left
# From M to I: right
# From M to M1: backward
# From M1 to M: forward
# From M1 to T: right
# From M1 to H: left
# From N to O: forward
# From N to V: right
# From N to K: left
# From O to P: forward
# ...

# %%
plt.figure(figsize=(10, 10))
pos = nx.spring_layout(graph, seed=42)
nx.draw(graph, pos, with_labels=True, node_size=1500, node_color='skyblue', font_size=12, font_weight='bold', arrowsize=20)

# Add edge labels for 'direction' attribute
edge_labels = nx.get_edge_attributes(graph, 'direction')
nx.draw_networkx_edge_labels(graph, pos, edge_labels=edge_labels, font_size=10, font_weight='bold')

# Show the plot
plt.title('Directed Graph with Edge Directions')
plt.axis('off')
plt.show()

# %%
# Save the graph in GraphML format
nx.write_graphml(graph, "real_ams_route.graphml")
